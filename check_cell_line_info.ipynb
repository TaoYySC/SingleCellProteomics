# %%
import pandas as pd

# %%
SCP_info = pd.read_csv("information.csv",index_col = 0)
SCP_info
# Out:
#      Index             Cell Name External link                  Species  \
# 0        1            Macrophage          N.A.     Mus musculus (Mouse)
# 1        1  Dopaminergic neurons          N.A.     Mus musculus (Mouse)
# 2        1                   U87     CVCL_0022     Homo sapiens (Human)
# 3        1            Brain cell          N.A.  Rattus norvegicus (Rat)
# 4        1   Primary tumour cell          N.A.     Homo sapiens (Human)
# ..     ...                   ...           ...                      ...
# 169      1                   C10     CVCL_A0TZ     Mus musculus (Mouse)
# 170      2             RAW 264.7     CVCL_0493     Mus musculus (Mouse)
# 171      3                  SVEC     CVCL_4393     Mus musculus (Mouse)
# 172      1                   C10     CVCL_A0TZ     Mus musculus (Mouse)
# 173      2                  SVEC     CVCL_4393     Mus musculus (Mouse)
#
#                    Organism part  \
# 0                    Bone marrow
# ...

# %%
Tissue = SCP_info['Organism part'].unique()
Tissue
# Out:
# array(['Bone marrow', 'Brain', 'Breast', 'Lung', 'Cervical',
#        'Embryo Kidney', 'Haematopoietic and Lymphoid', 'Pleural effusion',
#        'Colon', 'Vascular epithelium', 'Embryo', 'Ovary', 'Kidney',
#        'Pancreas', 'Skin', 'Spinal cord', 'Testis'], dtype=object)

# %%
Brain = SCP_info[SCP_info['Organism part'] == 'Brain']
Brain
# Out:
#    Index             Cell Name External link                  Species  \
# 1      1  Dopaminergic neurons          N.A.     Mus musculus (Mouse)
# 2      1                   U87     CVCL_0022     Homo sapiens (Human)
# 3      1            Brain cell          N.A.  Rattus norvegicus (Rat)
#
#   Organism part                                          Condition    SCP ID
# 1         Brain                                            Healthy  SCP43381
# 2         Brain  Glioblastoma\n                                ...  SCP37621
# 3         Brain                                            Healthy  SCP64515

# %%
Breast = SCP_info[SCP_info['Organism part'] == 'Breast']
Breast
# Out:
#     Index            Cell Name External link               Species  \
# 4       1  Primary tumour cell          N.A.  Homo sapiens (Human)
# 6       1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 7       1                MCF-7     CVCL_0031  Homo sapiens (Human)
# 8       1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 9       1                MCF-7     CVCL_0031  Homo sapiens (Human)
# 10      1           MDA-MB-231     CVCL_0062  Homo sapiens (Human)
# 11      1           MDA-MB-231     CVCL_0062  Homo sapiens (Human)
# 12      1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 64      1  Primary tumour cell          N.A.  Homo sapiens (Human)
#
#    Organism part                                          Condition    SCP ID
# 4         Breast  Breast cancer\n                               ...  SCP31060
# 6         Breast  Fibrocystic disease\n                         ...  SCP48732
# ...
