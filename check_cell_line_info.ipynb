# %%
import pandas as pd

# %%
SCP_info = pd.read_csv("information.csv",index_col = 0)
SCP_info
# Out:
#      Index             Cell Name External link                  Species  \
# 0        1            Macrophage          N.A.     Mus musculus (Mouse)
# 1        1  Dopaminergic neurons          N.A.     Mus musculus (Mouse)
# 2        1                   U87     CVCL_0022     Homo sapiens (Human)
# 3        1            Brain cell          N.A.  Rattus norvegicus (Rat)
# 4        1   Primary tumour cell          N.A.     Homo sapiens (Human)
# ..     ...                   ...           ...                      ...
# 169      1                   C10     CVCL_A0TZ     Mus musculus (Mouse)
# 170      2             RAW 264.7     CVCL_0493     Mus musculus (Mouse)
# 171      3                  SVEC     CVCL_4393     Mus musculus (Mouse)
# 172      1                   C10     CVCL_A0TZ     Mus musculus (Mouse)
# 173      2                  SVEC     CVCL_4393     Mus musculus (Mouse)
#
#                    Organism part  \
# 0                    Bone marrow
# ...

# %%
Tissue = SCP_info['Organism part'].unique()
Tissue
# Out:
# array(['Bone marrow', 'Brain', 'Breast', 'Lung', 'Cervical',
#        'Embryo Kidney', 'Haematopoietic and Lymphoid', 'Pleural effusion',
#        'Colon', 'Vascular epithelium', 'Embryo', 'Ovary', 'Kidney',
#        'Pancreas', 'Skin', 'Spinal cord', 'Testis'], dtype=object)

# %%
Brain = SCP_info[SCP_info['Organism part'] == 'Brain']
Brain
# Out:
#    Index             Cell Name External link                  Species  \
# 1      1  Dopaminergic neurons          N.A.     Mus musculus (Mouse)
# 2      1                   U87     CVCL_0022     Homo sapiens (Human)
# 3      1            Brain cell          N.A.  Rattus norvegicus (Rat)
#
#   Organism part                                          Condition    SCP ID
# 1         Brain                                            Healthy  SCP43381
# 2         Brain  Glioblastoma\n                                ...  SCP37621
# 3         Brain                                            Healthy  SCP64515

# %%
Breast = SCP_info[SCP_info['Organism part'] == 'Breast']
Breast
# Out:
#     Index            Cell Name External link               Species  \
# 4       1  Primary tumour cell          N.A.  Homo sapiens (Human)
# 6       1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 7       1                MCF-7     CVCL_0031  Homo sapiens (Human)
# 8       1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 9       1                MCF-7     CVCL_0031  Homo sapiens (Human)
# 10      1           MDA-MB-231     CVCL_0062  Homo sapiens (Human)
# 11      1           MDA-MB-231     CVCL_0062  Homo sapiens (Human)
# 12      1               MCF10A     CVCL_0598  Homo sapiens (Human)
# 64      1  Primary tumour cell          N.A.  Homo sapiens (Human)
#
#    Organism part                                          Condition    SCP ID
# 4         Breast  Breast cancer\n                               ...  SCP31060
# 6         Breast  Fibrocystic disease\n                         ...  SCP48732
# ...

# %%
Lung = SCP_info[SCP_info['Organism part'] == 'Lung']
Lung
# Out:
#     Index                    Cell Name External link               Species  \
# 5       2  Lung metastasis tumour cell          N.A.  Homo sapiens (Human)
# 65      2  Lung metastasis tumour cell          N.A.  Homo sapiens (Human)
# 66      1                         PC-9     CVCL_B260  Homo sapiens (Human)
# 67      1                         PC-9     CVCL_B260  Homo sapiens (Human)
# 68      1                 Primary cell          N.A.  Homo sapiens (Human)
#
#    Organism part                                          Condition    SCP ID
# 5           Lung  Lung cancer\n                                 ...  SCP31060
# 65          Lung  Lung cancer\n                                 ...  SCP31060
# 66          Lung  Lung cancer\n                                 ...  SCP18981
# 67          Lung  Lung cancer\n                                 ...  SCP22919
# 68          Lung                                            Healthy  SCP45832

# %%
Cervical = SCP_info[SCP_info['Organism part'] == 'Cervical']
Cervical
# Out:
#      Index Cell Name External link               Species Organism part  \
# 13       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 15       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 17       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 18       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 19       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 20       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 21       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 22       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 23       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 24       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 25       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# 26       1      HeLa     CVCL_0030  Homo sapiens (Human)      Cervical
# ...

# %%
EmbryoKidney = SCP_info[SCP_info['Organism part'] == 'Embryo Kidney']
EmbryoKidney
# Out:
#      Index Cell Name External link               Species  Organism part  \
# 14       2    HEK293     CVCL_0045  Homo sapiens (Human)  Embryo Kidney
# 47       2    HEK293     CVCL_0045  Homo sapiens (Human)  Embryo Kidney
# 61       1    HEK293     CVCL_0045  Homo sapiens (Human)  Embryo Kidney
# 147      1    HEK293     CVCL_0045  Homo sapiens (Human)  Embryo Kidney
#
#     Condition    SCP ID
# 14    Healthy  SCP20927
# 47    Healthy  SCP20927
# 61    Healthy  SCP47204
# 147   Healthy  SCP47204

# %%
HaematopoieticLymphoid = SCP_info[SCP_info['Organism part'] == 'Haematopoietic and Lymphoid']
HaematopoieticLymphoid
# Out:
#      Index  Cell Name External link               Species  \
# 16       2       K562     CVCL_0004  Homo sapiens (Human)
# 33       2  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# 35       2  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# 39       2  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# 42       2  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# ..     ...        ...           ...                   ...
# 149      1     Jurkat     CVCL_0065  Homo sapiens (Human)
# 151      1     Jurkat     CVCL_0065  Homo sapiens (Human)
# 165      1  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# 167      1  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
# 170      2  RAW 264.7     CVCL_0493  Mus musculus (Mouse)
#
#                    Organism part  \
# 16   Haematopoietic and Lymphoid
# 33   Haematopoietic and Lymphoid
# 35   Haematopoietic and Lymphoid
# 39   Haematopoietic and Lymphoid
# 42   Haematopoietic and Lymphoid
# ..                           ...
# ...

# %%
SCP_info['Cell Name'].unique()
# Out:
# array(['Macrophage', 'Dopaminergic neurons', 'U87', 'Brain cell',
#        'Primary tumour cell', 'Lung metastasis tumour cell', 'MCF10A',
#        'MCF-7', 'MDA-MB-231', 'HeLa', 'HEK293', 'K562', 'U-937', 'C10',
#        'RAW 264.7', 'SVEC', 'Embryonic cell', 'Hair cell', 'Egg',
#        'Left dorsal-animal (L-D1) cell', 'Left ventral-animal(L-V1)cell',
#        'Embryonic stem cell', 'Kindney cell', 'PC-9', 'Primary cell',
#        'Oocyte', 'HPAF-II', 'CFPAC-I', 'WM989 A6-G3', 'MOLM-14', 'CMK',
#        'Leukemic stem cells', 'Progenitors(PROG)', 'Blast cell',
#        'Terminally differentiated blasts', 'MEC-1', 'Jurkat',
#        'Motor neurons (MNs)', 'Interneurons(INs)', 'GC-1 spg', 'GC-2 spd'],
#       dtype=object)

# %%
ImmuneCell = ['Macrophage','K562','U-937','RAW 264.7','MOLM-14','CMK','Leukemic stem cells','Progenitors (PROG)','MEC-1','Jurkat']

# %%
Macrophage = SCP_info[SCP_info['Cell Name'] == 'Macrophage']
Macrophage
# Out:
#    Index   Cell Name External link               Species Organism part  \
# 0      1  Macrophage          N.A.  Mus musculus (Mouse)   Bone marrow
#
#   Condition    SCP ID
# 0   Healthy  SCP46620

# %%
K562 = SCP_info[SCP_info['Cell Name'] == 'K562']
K562
# Out:
#      Index Cell Name External link               Species  \
# 16       2      K562     CVCL_0004  Homo sapiens (Human)
# 79       2      K562     CVCL_0004  Homo sapiens (Human)
# 82       2      K562     CVCL_0004  Homo sapiens (Human)
# 94       1      K562     CVCL_0004  Homo sapiens (Human)
# 105      2      K562     CVCL_0004  Homo sapiens (Human)
# 107      1      K562     CVCL_0004  Homo sapiens (Human)
# 116      2      K562     CVCL_0004  Homo sapiens (Human)
# 121      2      K562     CVCL_0004  Homo sapiens (Human)
# 136      2      K562     CVCL_0004  Homo sapiens (Human)
#
#                    Organism part  \
# 16   Haematopoietic and Lymphoid
# 79   Haematopoietic and Lymphoid
# 82   Haematopoietic and Lymphoid
# 94   Haematopoietic and Lymphoid
# 105  Haematopoietic and Lymphoid
# 107  Haematopoietic and Lymphoid
# 116  Haematopoietic and Lymphoid
# 121  Haematopoietic and Lymphoid
# 136  Haematopoietic and Lymphoid
#
# ...

# %%
U937 = SCP_info[SCP_info['Cell Name'] == 'U-937']
U937
# Out:
#      Index Cell Name External link               Species     Organism part  \
# 28       1     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 62       2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 75       1     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 118      1     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 140      2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 142      2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 143      1     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 145      1     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 148      2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 150      2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# 152      2     U-937     CVCL_0007  Homo sapiens (Human)  Pleural effusion
# ...

# %%
U937['SCP ID'].unique()
# Out:
# array(['SCP76140', 'SCP47204', 'SCP50571', 'SCP94901', 'SCP47730',
#        'SCP61852'], dtype=object)
