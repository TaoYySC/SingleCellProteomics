# %%
# !pip install fcsparser
# Out:
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.6 MB 2.4 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/14.6 MB 3.1 MB/s eta 0:00:05
#    ------ --------------------------------- 2.4/14.6 MB 3.6 MB/s eta 0:00:04
#    --------- ------------------------------ 3.4/14.6 MB 4.5 MB/s eta 0:00:03
#    ------------- -------------------------- 5.0/14.6 MB 4.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.0/14.6 MB 4.9 MB/s eta 0:00:02
#    -------------------- ------------------- 7.3/14.6 MB 5.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.7/14.6 MB 5.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.5/14.6 MB 5.5 MB/s eta 0:00:01
# ...

# %%
import fcsparser
data, meta = fcsparser.parse("FC-based-SCP/Bone marrow/SCP43132/D0.fcs")
data
# Out:
# {'__header__': {'FCS format': b'FCS3.0',
#   'text start': 58,
#   'text end': 5562,
#   'data start': 5563,
#   'data end': 289194,
#   'analysis start': 0,
#   'analysis end': 0},
#  '$BEGINANALYSIS': '0',
#  '$BEGINDATA': '5563',
#  '$BEGINSTEXT': '0',
#  '$BTIM': '17:24:23',
#  '$BYTEORD': '4,3,2,1',
#  '$CYT': 'LSRFortessa',
#  '$DATATYPE': 'F',
#  '$DATE': '26-JUN-2019',
#  '$ENDANALYSIS': '0',
#  '$ENDDATA': '289194',
#  '$ENDSTEXT': '0',
#  '$ETIM': '17:31:52',
#  '$FIL': '20190626 D0_D0-1_012.fcs',
#  '$INST': ' ',
#  '$MODE': 'L',
#  '$NEXTDATA': 0,
#  '$OP': 'Administrator',
#  '$P10B': 32,
#  '$P10E': '0,0',
#  '$P10G': '1.0',
#  '$P10N': 'APC-Alexa 700-A',
#  '$P10R': '262144',
#  '$P10V': '525',
#  '$P11B': 32,
#  '$P11E': '0,0',
#  '$P11G': '1.0',
#  '$P11N': 'BV421-A',
#  '$P11R': '262144',
#  '$P11S': 'CD90',
#  '$P11V': '400',
#  '$P12B': 32,
#  '$P12E': '0,0',
#  '$P12G': '1.0',
#  '$P12N': 'BV510-A',
#  '$P12R': '262144',
#  '$P12S': 'CD45RA',
#  '$P12V': '450',
# ...

# %%
meta
# Out:
#               FSC-A    FSC-H          FSC-W          SSC-A     SSC-H  \
# 0     130600.125000  90929.0   94128.507812   79235.515625   60819.0
# 1      80957.398438  50072.0  105959.906250  153183.421875   90126.0
# 2      86921.000000  59944.0   95029.609375   77050.734375   64142.0
# 3      83079.679688  55175.0   98680.742188  101953.796875   76017.0
# 4      98506.843750  58232.0  110862.492188  139708.921875   97454.0
# ...             ...      ...            ...            ...       ...
# 3727  126516.718750  76945.0  107757.484375  150018.953125  110503.0
# 3728  107032.000000  60828.0  115316.125000  158610.656250  107706.0
# 3729   66205.484375  39025.0  111181.109375  124935.718750   90727.0
# 3730  101723.921875  55613.0  119874.476562  135542.937500   93051.0
# 3731   56921.441406  39437.0   94591.460938   91006.500000   73695.0
#
#               SSC-W        CD43       7-AAD       CD34  APC-Alexa 700-A  \
# ...
